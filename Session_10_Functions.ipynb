# %% [markdown]
# **Functions or Methods**
# - Reuse of code
#
#
# - Functions with out arguments
#
# - Functions with arguments
#
# - Functions with default arguments
#
# - Global variable vs Local variable
#
# - Functions with return statement
#
# - Functions with kwargs
#
# - Functions in functions

# %%
# syntax 
def <function name>():
<write your code here>

# %% [markdown]
# **Function with out arguments**
#
# - The function we defined does not have any values or variables
# - These also called as arguments or parameters
# - simply it is a empty bracket

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
add=n1+n2
print(f"the addition of {n1},{n2} is: {add}")
# Out:
# enter the n1: 78
# enter the n2: 22
# the addition of 78,22 is: 100

# %%
def addition():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    add=n1+n2
    print(f"the addition of {n1},{n2} is: {add}")

# %%
# Function is ready 
# creating function means it will not give th answer
 # you need to call the function
addition()
# Out:
# enter the n1: 45
# enter the n2: 55
# the addition of 45,55 is: 100

# %%
addition
# Out:
# <function __main__.addition()>

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000002B56BD66450>>

# %% [markdown]
# **Note**
# - while calling the function we need to use the function name
# - also we need to provide brackets
# - in python brackets indicates it is a function or method
# - if we miss the brackets , it will display as
#    - function
#    - bound method

# %%
a= 10

# %%
name='python'

# %%
addition()
# Out:
# enter the n1: 45
# enter the n2: 65
# the addition of 45,65 is: 110

# %% [markdown]
# **Note**
# - Once we create the function we can use anywhere inthe same notebook
# - if you want to use in another notebook
# - we need to create as Package (OOPS)

# %%
addition1()
def addition1():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    add=n1+n2
    print(f"the addition of {n1},{n2} is: {add}")

# The above code will give the error
# before call the function first we need to define the function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 addition1()
#       2 def addition1():
#       3     n1=eval(input('enter the n1:'))
#
# NameError: name 'addition1' is not defined

# %%
# wap ask the user take three numbers from keyboard and print average
 #        (n1+n2+n3)/3

def average():
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    n3=eval(input("enter the n3:"))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average()
# Out:
# enter the n1: 45
# enter the n2: 55
# enter the n3: 50
# the avg of 45,55 and 50 is 50.0

# %%
# Wap ask the user take the breadth and height from keyboard
      # calculate area of right angle traingle
      # Formula= 0.5*b*h


def area_of_traingle():
    b=eval(input('enter the breadth:'))
    h=eval(input('enter the height:'))
    area=0.5*b*h
    print(f"the area is:{area}")
area_of_traingle()
# Out:
# enter the breadth: 100
# enter the height: 56
# the area is:2800.0

# %% [markdown]
# **Note**
# - Variable names should not equal to function names

# %%
try:
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    n3=eval(input("enter the n3:"))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
except Exception as e:
    print(e)
# Out:
# enter the n1: 78
# enter the n2: 54
# enter the n3: 78
# the avg of 78,54 and 78 is 70.0

# %%
def AVERAGE():
    try:
        n1=eval(input("enter the n1:"))
        n2=eval(input("enter the n2:"))
        n3=eval(input("enter the n3:"))
        avg=(n1+n2+n3)/3
        print(f"the avg of {n1},{n2} and {n3} is {avg}")
    except Exception as e:
        print(e)
AVERAGE()
# Out:
# enter the n1: 45
# enter the n2: 65
# enter the n3: 87
# the avg of 45,65 and 87 is 65.66666666666667

# %%
try:
    def average():
        n1=eval(input("enter the n1:"))
        n2=eval(input("enter the n2:"))
        n3=eval(input("enter the n3:"))
        avg=(n1+n2+n324)/3
        print(f"the avg of {n1},{n2} and {n3} is {avg}")
except Exception as e:
    print(e)
average()
# Out:
# enter the n1: 45
# enter the n2: 65
# enter the n3: 55
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 10
#       8 except Exception as e:
#       9     print(e)
# ---> 10 average()
#
# Cell In[23], line 6, in average()
#       4 n2=eval(input("enter the n2:"))
#       5 n3=eval(input("enter the n3:"))
# ----> 6 avg=(n1+n2+n324)/3
#       7 print(f"the avg of {n1},{n2} and {n3} is {avg}")
#
# NameError: name 'n324' is not defined

# %%
try:
    def average():
        n1=eval(input("enter the n1:"))
        n2=eval(input("enter the n2:"))
        n3=eval(input("enter the n3:"))
        avg=(n1+n2+n3)/3
        print(f"the avg of {n1},{n2} and {n3} is {avg}")
except Exception as e:
      print(e)
average()
# Out:
# enter the n1: 45
# enter the n2: 55
# enter the n3: 60
# the avg of 45,55 and 60 is 53.333333333333336

# %% [markdown]
# **Note**
#
# - always give try and except for only on code
#
# - Not for function
#
# - Inside the function write try-except

# %%
def average():
    try:
        n1=eval(input("enter the n1:"))
        n2=eval(input("enter the n2:"))
        n3=eval(input("enter the n3:"))
        avg=(n1+n2+n3)/3
        print(f"the avg of {n1},{n2} and {n3} is {avg}")
    except Exception as e:
        print(e)

average()
# Out:
# enter the n1: 45
# enter the n2: 89
# enter the n3: 87
# the avg of 45,89 and 87 is 73.66666666666667

# %%
from math import pi
def average():
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    n3=eval(input("enter the n3:"))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
average()
############################################################
def area_of_traingle():
    b=eval(input('enter the breadth:'))
    h=eval(input('enter the height:'))
    area=0.5*b*h
    print(f'the area is:{area}')
area_of_traingle()
 ##########################################################
def area_of_circle():
    r=eval(input("enter the radius:"))
    area=pi*r*r
    print(f"area of circle:{area}")
area_of_circle()
 ##########################################################
def bill():
    billamount=eval(input("enter the bill amount:"))
    tipamount=eval(input("enter the tip amount:"))
    totalbill=billamount+tipamount
    print(f"the total bill is :{totalbill}")
bill()
# Out:
# enter the n1: 45
# enter the n2: 65
# enter the n3: 78
# the avg of 45,65 and 78 is 62.666666666666664
# enter the breadth: 20
# enter the height: 30
# the area is:300.0
# enter the radius: 45
# area of circle:6361.725123519332
# enter the bill amount: 500
# enter the tip amount: 50
# the total bill is :550

# %%
from math import pi
def average():
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    n3=eval(input("enter the n3:"))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average()

#############################################################

def area_of_traingle():
    b=eval(input('enter the breadth:'))
    h=eval(input('enter the height:'))
    area=0.5*b*h
    print(f'the area is:{area}')

###############################################################

def area_of_circle():
    r=eval(input("enter the radius:"))
    area=pi*r*r
    print(f"area of circle:{area}")
 ##########################################################
def bill():
    billamount=eval(input("enter the bill amount:"))
    tipamount=eval(input("enter the tip amount:"))
    totalbill=billamount+tipamount
    print(f"the total bill is :{totalbill}")
# Out:
# enter the n1: 45
# enter the n2: 78
# enter the n3: 98
# the avg of 45,78 and 98 is 73.66666666666667

# %%
print("Average function starts")
average()
print("Area of circle function starts")
area_of_circle()
print("Area of traingle function starts")
area_of_traingle()
print("bill amount function starts")
bill()
# Out:
# Average function starts
# enter the n1: 78
# enter the n2: 89
# enter the n3: 90
# the avg of 78,89 and 90 is 85.66666666666667
# Area of circle function starts
# enter the radius: 78
# area of circle:19113.4497044403
# Area of traingle function starts
# enter the breadth: 98
# enter the height: 7.5
# the area is:367.5
# bill amount function starts
# enter the bill amount: 500
# enter the tip amount: 50
# the total bill is :550

# %%
def average2():
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    n3=eval(input("enter the n3:"))
    avg=(n1+n222+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
average2()
# Out:
# enter the n1: 95
# enter the n2: 96
# enter the n3: 85
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       5     avg=(n1+n222+n3)/3
#       6     print(f"the avg of {n1},{n2} and {n3} is {avg}")
# ----> 7 average2()
#
# Cell In[16], line 5, in average2()
#       3 n2=eval(input("enter the n2:"))
#       4 n3=eval(input("enter the n3:"))
# ----> 5 avg=(n1+n222+n3)/3
#       6 print(f"the avg of {n1},{n2} and {n3} is {avg}")
#
# NameError: name 'n222' is not defined

# %% [markdown]
# **Note**
# - when we define th function , it will not give any error or any answer
# - If we want to see any error or any answer we need to call the function

# %%
average()
area_of_circle()
area_of_traingle()
bill()
# Out:
# enter the n1: 45
# enter the n2: 65
# enter the n3: 45
# the avg of 45,65 and 45 is 51.666666666666664
# enter the radius: 55
# area of circle:9503.317777109125
# enter the breadth: 45
# enter the height: 7.6
# the area is:171.0
# enter the bill amount: 654
# enter the tip amount: 54
# the total bill is :708

# %% [markdown]
# **Functions with Arguments**
#
# - let's create an addition program code

# %%
def addition():
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    add=n1+n2
    print(f"the addition of {n1} and {n2} is:{add}")

addition()
# Out:
# enter the n1: 45
# enter the n2: 55
# the addition of 45 and 55 is:100

# %% [markdown]
# - how many variables are there in above code: 3
#     - n1,n2,add
# - what are the input variables
#      - n1,n2
# - what are the output variables
#      - add
# - pass the input variables inside the function brackets
#
# - pass n1,n2 inside the brackets, these n1,n2 behave as function arguments

# %%
addition1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 addition1()
#
# NameError: name 'addition1' is not defined

# %%
from random import randint
randint(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 from random import randint
# ----> 2 randint(10)
#
# TypeError: Random.randint() missing 1 required positional argument: 'b'

# %%
from math import pi
def average():
    n1=eval(input("enter the n1:"))
    n2=eval(input("enter the n2:"))
    n3=eval(input("enter the n3:"))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
 ############################################################
def area_of_traingle():
    b=eval(input('enter the breadth:'))
    h=eval(input('enter the height:'))
    area=0.5*b*h
    print(f'the area is:{area}')
 ##########################################################
def area_of_circle():
    r=eval(input("enter the radius:"))
    area=pi*r*r
    print(f"area of circle:{area}")
 ##########################################################
def bill():
    billamount=eval(input("enter the bill amount:"))
    tipamount=eval(input("enter the tip amount:"))
    totalbill=billamount+tipamount
    print(f"the total bill is :{totalbill}")
def average(n1,n2,n3):
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
average(10,20,30)
# Out:
# the avg of 10,20 and 30 is 20.0

# %%
def average(n1,n2,n3):
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
average(10,20,30)
# Out:
# the avg of 10,20 and 30 is 20.0

# %%
def area_of_traingle(b,h):
    print('b:',b)
    print('h:',h)
    area=0.5*b*h
    print(f'the area is:{area}')

area_of_traingle(45,20)
# Out:
# b: 45
# h: 20
# the area is:450.0

# %%
from math import pi
def area_of_circle(r):
    area=pi*r*r
    print(f"area of circle:{area}")

area_of_circle(10)
# Out:
# area of circle:314.1592653589793

# %%
def bill(billamount,tipamount):
    try:
        totalbill=billamount+tipamount
        print(f"the total bill is :{totalbill}")
    except Exception as e:
        print(e)

bill(1500,20)
# Out:
# the total bill is :1520

# %%
def average(n1,n2):
    print('n1:',n1)
    print('n2:',n2)
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average(10,20)
# Out:
# n1: 10
# n2: 20
# enter the n3: 55
# the avg of 10,20 and 55 is 28.333333333333332

# %%
def average(n1):
    print('n1:',n1)
    n2=eval(input('enter the n2:'))
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"The avg of {n1},{n2} and {n3} is {avg}")

average(10)
# Out:
# n1: 10
# enter the n2: 45
# enter the n3: 87
# The avg of 10,45 and 87 is 47.333333333333336

# %%
def average(n1,n2,n3):
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

# %%
def average(n1,n2):
    print('n1:',n1)
    print('n2:',n2)
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

def average(n1):
    print('n1:',n1)
    n2=eval(input('enter the n2:'))
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")
    
def average():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

# %%
2**2
2**3
2**4
number=eval(input('enter the number:'))
power=eval(input('how much power we want:'))
print(number**power)
# Out:
# enter the number: 18
# how much power we want: 2
# 324

# %%
def POWER():
    number=eval(input('enter the number:'))
    power=eval(input('how much power we want:'))
    print(number**power)

POWER()
# Out:
# enter the number: 3
# how much power we want: 2
# 9

# %%
def POWER(number,power):
    print(number**power)

POWER(2,3)
# Out:
# 8

# %%
def POWER():
    number=eval(input('enter the number:'))
    power=eval(input('how much power we want:'))
    print(number**power)

POWER(30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 6
#       3     power=eval(input('how much power we want:'))
#       4     print(number**power)
# ----> 6 POWER(30)
#
# TypeError: POWER() takes 0 positional arguments but 1 was given

# %%
def average(n1,n2,n3):
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

# %% [markdown]
# **Function with Default argument**

# %%
def bill(billamount,tipamount=500):
    totalbill=billamount+tipamount
    print(f"the total bill is :{totalbill}")

bill(2000)
# Out:
# the total bill is :2500

# %%
def average(n1,n2,n3=40):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average(10,20)
# Out:
# n1: 10
# n2: 20
# n3: 40
# the avg of 10,20 and 40 is 23.333333333333332

# %%
def average(n1,n2=40,n3):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average(10,20)
# Out:
#   Cell In[96], line 1
#     def average(n1,n2=40,n3):
#                          ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# **always write the default arguments at last**

# %%
def average(n1,n3,n2=40):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average(10,20)
# Out:
# n1: 10
# n2: 40
# n3: 20
# the avg of 10,40 and 20 is 23.333333333333332

# %%
def average(n3,n2,n1=50):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average(10,20)
# Out:
# n1: 50
# n2: 20
# n3: 10
# the avg of 50,20 and 10 is 26.666666666666668

# %%
n1,n2,n3=100  # works
n1,n2=100,n3  # F
n1=100,n2,n3  # F
n1,n2=100,n3=200 # W 
n1=100,n2,n3=200 # F
n1=100,n2=100,n3 # F
n1=100,n2=200,n3=300 # W
n3,n1=100,n2=200 # W
n2,n3=200,n1=500 # w

# %%
# with out arguments
# with arguments
# default arguments


# wap ask the user enter a number 
# ask the user get a random number
# if both numbers are match print won
# otherwise lost

# %%
import random
num1=random.randint(1,10)
num2=eval(input("enter the num2:"))
if num1==num2:
    print('won')
else:
    print('lost')
# Out:
# enter the num2: 9
# lost

# %%
def game1():
    num1=random.randint(1,10)
    num2=eval(input("enter the num2:"))
    if num1==num2:
        print("won")
    else:
        print('lost')
game1()
# Out:
# enter the num2: 10
# lost

# %%
def game2(num2):
    num1=random.randint(1,10)
    if num1==num2:
        print("won")
    else:
        print('lost')
game2(8)
# Out:
# lost

# %%
def game3(num2=5):
    num1=random.randint(1,10)
    if num1==num2:
        print("won")
    else:
        print('lost')
game3()
# Out:
# lost

# %% [markdown]
# **Case-1**
# - Step1: Define the function
# - Step2: Call the function
# - Step3: run the function

# %%
def average(n1,n2,n3=40):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average(10,20,100)

# while defineing n3=40
# while calling n3=100
# while running also n3=100
# Out:
# n1: 10
# n2: 20
# n3: 100
# the avg of 10,20 and 100 is 43.333333333333336

# %%
def add(a,b,c=50):
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    print(d)

add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 100
# 130

# %%
def add(a,b,c=50):
    c=500
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    print(d)

# %%
def add(a,b,c=50):
    c=500
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    print(d)

add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 500
# 530

# %%
def add(a,b,c=50):
    c=500
    print('a:',a)
    print('b:',b)
    print('c:',c)
    c=1000
    d=a+b+c
    print(d)

add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 500
# 1030

# %%
def add(a,b,c=50):
    print('a:',a) # 10
    print('b:',b) # 20
    print('c:',c)
    d=a+b+c       
    print(d)
print('follow the step by step')
c=700
add(10,20,100)

# defining ==== c=50
# c=700
# calling  100
# Out:
# follow the step by step
# a: 10
# b: 20
# c: 100
# 130

# %%
def add(a,b,c=50):
    c=800
    print('a:',a)
    print('b:',b)
    print('c:',c)
    c=900
    d=a+b+c
    print(d)
c=700
add(10,20,100)

# def==== c=50
#  c=700
# c=100
# c=800
# c=900===
# Out:
# a: 10
# b: 20
# c: 800
# 930

# %%
c=900
def add(a,b,c=50):
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    print(d)
add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 100
# 130

# %%
c=200
def add(a,b,c=50):
    c=400
    print('a',a)
    print('b',b)
    print('c',c)
    d=a+b+c
    c=500
    print(d)
c=300
add(10,20,100)
# Out:
# a 10
# b 20
# c 400
# 430

# %%
c=200
def add(a,b,c=50):
    c=400
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    c=500
    print(d)
    print(c)
c=300
add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 400
# 430
# 500

# %%
c=200
def add(a,b,c):
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    print(d)
    print(c)
add(10,20,30)
# Out:
# a: 10
# b: 20
# c: 30
# 60
# 30

# %% [markdown]
# **local variable vs Global variable**
#  - local variables are used inside the function
#
#  - global variables are used outside the function
#
#  - global variables can be used at anywhere inside the function or outside the
#  function

# %%
from math import pi
def average():
n1=eval(input("enter the n1:"))
n2=eval(input("enter the n2:"))
n3=eval(input("enter the n3:"))
avg=(n1+n2+n3)/3
print(f"the avg of {n1},{n2} and {n3} is {avg}")
############################################################
def area_of_traingle():
b=eval(input('enter the breadth:'))
h=eval(input('enter the height:'))
area=0.5*b*h
print(f'the area is:{area}')
##########################################################
def area_of_circle():
r=eval(input("enter the radius:"))
area=pi*r*r
print(f"area of circle:{area}")
##########################################################
def bill():
billamount=eval(input("enter the bill amount:"))
tipamount=eval(input("enter the tip amount:"))
totalbill=billamount+tipamount
print(f"the total bill is :{totalbill}")

# %%
n1=eval(input("enter the n1:"))
n2=eval(input("enter the n2:"))
n3=eval(input("enter the n3:"))
def average():
    avg=(n1+n2+n3)/3
    print(f"the avg of {n1},{n2} and {n3} is {avg}")

average()
# Out:
# enter the n1: 45
# enter the n2: 55
# enter the n3: 65
# the avg of 45,55 and 65 is 55.0

# %%
print(n1,n2,n3)
# Out:
# 45 55 65

# %%
def average1():
    N1=eval(input("enter the n1:"))
    N2=eval(input("enter the n2:"))
    N3=eval(input("enter the n3:"))
    avg=(N1+N2+N3)/3
    print(f"the avg of {N1},{N2} and {N3} is {avg}")

average1()
# Out:
# enter the n1: 45
# enter the n2: 65
# enter the n3: 55
# the avg of 45,65 and 55 is 55.0

# %%
print(N1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(N1)
#
# NameError: name 'N1' is not defined

# %% [markdown]
# **Note**
# - Local variables can not use outside the function
#
# - in above code N1 is a local variable
#
# - we are trying to use outside the function it is throwing the error

# %%
A=eval(input("enter the n1:"))
B=eval(input("enter the n2:"))
C=eval(input("enter the n3:"))
def average3():
    avg=(A+B+C)/3
    print(f"the avg of {A},{B} and {C} is {avg}")

average3()
# Out:
# enter the n1: 55
# enter the n2: 66
# enter the n3: 70
# the avg of 55,66 and 70 is 63.666666666666664

# %%
avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 avg
#
# NameError: name 'avg' is not defined

# %% [markdown]
# - gloabl variables are intialized outside the function
#
# - global varaibles can be use anywhere
#
# - local varaibles are intialized inside the function
#
# - local variables can not use outside the function

# %%
A=100
B=200
####################################
def summ(A=4000):
    C=300
    A=8000
    add=A+B+C
    print(f"the avg of {A},{B} and {C} is {add}")
 #################################################
 A=2000
 ###########################################
 summ(A=3000)

# A=100
# B=200
# Defining === A=100
# A=2000
# calling
# Out:
#   File <string>:10
#     A=2000
#           ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# **how to use local variables outside the function call**

# %%
A=100
B=200
C=300
def add1():
    global ADD
    ADD=A+B+C
    print(f"the addition of {A},{B} and {C} is {ADD}")

add1()
# Out:
# the addition of 100,200 and 300 is 600

# %%
ADD
# Out:
# 600

# %% [markdown]
# - Local variables can use outside the function in two ways
#
# - by making local variable as global by using global
#
# - by using return statement also

# %%
n1=eval(input('enter a number:'))
n2=eval(input('enter a number:'))
n3=eval(input('enter a number:'))
def average():
    global avg
    avg=(n1+n2+n3)/3
    print(f'the average is {avg}')
average()
print(avg)
# Out:
# enter a number: 45
# enter a number: 55
# enter a number: 60
# the average is 53.333333333333336
# 53.333333333333336

# %%
12345
54678
# Out:
# 54678

# %%
12345//10,12345%10
# Out:
# (1234, 5)

# %%
1234//10,1234%10
# Out:
# (123, 4)

# %%
population=80000
menspopulation=population*52/100

# %%
180%10
# Out:
# 0

# %%
def summ(a,b):
    global add,sub
    add=a+b
    sub=a-b
    print(add,sub)
summ(20,30)
# Out:
# 50 -10

# %% [markdown]
# **unbound local error**
#
# - unbound local error means the variable is not defined
#
# - that variable is used as both input and output inside the function

# %%
def fun1():
    a=10
    b=b+a
    print(b)
fun1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[48], line 5
#       3     b=b+a
#       4     print(b)
# ----> 5 fun1()
#
# Cell In[48], line 3, in fun1()
#       1 def fun1():
#       2     a=10
# ----> 3     b=b+a
#       4     print(b)
#
# UnboundLocalError: cannot access local variable 'b' where it is not associated with a value

# %%
def fun2():
    a=10
    c=b+a
    print(c)
fun2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 5
#       3     c=b+a
#       4     print(c)
# ----> 5 fun2()
#
# Cell In[50], line 3, in fun2()
#       1 def fun2():
#       2     a=10
# ----> 3     c=b+a
#       4     print(c)
#
# NameError: name 'b' is not defined

# %%
a=10
b=b+a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 a=10
# ----> 2 b=b+a
#
# NameError: name 'b' is not defined

# %% [markdown]
# **return statement**
#
# - till now above we have created a function with print statement in order to see the
#  output
#
# - the function output we are not able to use outside the function
#
# - because it is a local variable
#
# - one method we used to is **global**
#
# - another method is return statement
#
# - return means some thing we are recieving
#
# - print means only we can see the answer

# %%
def add(a,b):
    c=a+b
    return(c)
val1=add(20,30)

# %%
val1
# Out:
# 50

# %%
def add_sub(a,b):
    summ=a+b
    sub=a-b
    print(summ,sub)
    return(summ,sub)
summ,sub=add_sub(200,100)
# Out:
# 300 100

# %%
def add_sub(a,b):
    summ=a+b
    sub=a-b
    print(summ,sub)
    return(summ,sub)
sub,summ=add_sub(200,100)
# Out:
# 300 100

# %%
print(summ)
print(sub)
# Out:
# 100
# 300

# %%
def add_sub(a,b):
    summ=a+b
    sub=a-b
    return(summ)
    return(sub)
add_sub(200,300)
# Out:
# 500

# %%
n1=100,200 # w
n1,n2=100,200 # w
n1,n2=100 # F

# %%
n1=100,200
n1
# Out:
# (100, 200)

# %%
def add_sub(a,b):
    summ=a+b
    sub=a-b
    return(summ,sub)

op=add_sub(200,300)

# %%
op
# Out:
# (500, -100)

# %%
 def add(a,b):
    c=a+b
    return(c)
 val1=add(20,30)
 ###########################################
 def add_sub(a,b):
    summ=a+b
    sub=a-b
    print(summ,sub)
    return(summ,sub)
 n1,n2=add_sub(200,100)
 ########################################
 def add_sub(a,b):
    summ=a+b
    sub=a-b
    return(summ,sub)
 op=add_sub(200,300)

# %%
n1,n2=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 n1,n2=100
#
# TypeError: cannot unpack non-iterable int object

# %%
n1,n2=100,200
n1=100,200 # tuple

# %% [markdown]
# **global vs return**
#
# - global keyword used for we can take the inside variable to outside the function
#
# - return can return any value outside the function

# %% [markdown]
# **the value you return can be used another notebook also**

# %% [markdown]
# **function in functions**

# %%
def greet1():
    print("Hello good morning")

# %%
def greet2():
    print("hello good night")

greet1()
greet2()
# Out:
# Hello good morning
# hello good night

# %%
def greet1():
    print("hello good morning")

def greet2():
    print("greet1 function starts")
    greet1()
    print("hello good night")

greet2()
# Out:
# greet1 function starts
# hello good morning
# hello good night

# %%
def greet1():
    print("greet2 function starts")
    greet2()
    print("hello good morning")

def greet2():
    print("hello good night")

greet1()
# Out:
# greet2 function starts
# hello good night
# hello good morning

# %%
def greet1():
    print("greet2 function starts")
    greet2()
    print("hello good morning")

def greet2():
    print("greet1 function starts")
    greet1()
    print("hello good night")

greet2()
# Out:
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# ...
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[106], line 11
#       8     greet1()
#       9     print("hello good night")
# ---> 11 greet2()
#
# Cell In[106], line 8, in greet2()
#       6 def greet2():
#       7     print("greet1 function starts")
# ----> 8     greet1()
#       9     print("hello good night")
#
# Cell In[106], line 3, in greet1()
#       1 def greet1():
#       2     print("greet2 function starts")
# ----> 3     greet2()
#       4     print("hello good morning")
#
# Cell In[106], line 8, in greet2()
#       6 def greet2():
#       7     print("greet1 function starts")
# ----> 8     greet1()
#       9     print("hello good night")
#
# Cell In[106], line 3, in greet1()
#       1 def greet1():
#       2     print("greet2 function starts")
# ----> 3     greet2()
#       4     print("hello good morning")
#
#     [... skipping similar frames: greet2 at line 8 (1485 times), greet1 at line 3 (1484 times)]
#
# Cell In[106], line 3, in greet1()
#       1 def greet1():
#       2     print("greet2 function starts")
# ----> 3     greet2()
#       4     print("hello good morning")
#
# Cell In[106], line 8, in greet2()
#       6 def greet2():
#       7     print("greet1 function starts")
# ----> 8     greet1()
#       9     print("hello good night")
#
# Cell In[106], line 2, in greet1()
#       1 def greet1():
# ----> 2     print("greet2 function starts")
#       3     greet2()
#       4     print("hello good morning")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\iostream.py:664, in OutStream.write(self, string)
#     655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)
#     662
#     663     """
# --> 664     parent = self.parent_header
#     666     if not isinstance(string, str):
#     667         msg = f"write() argument must be str, not {type(string)}"  # type:ignore[unreachable]
#
# RecursionError: maximum recursion depth exceeded

# %%
def greet1():
    print("hello good morning")

def greet2():
    print("hello good night")

greet1()
greet2()
#################################################
def greet1():
    print("hello good morning")
def greet2():
    print("greet1 function starts")
    greet1()
    print("hello good night")
greet2()
###################################################
def greet1():
    print("greet2 function starts")
    greet2()
    print("hello good morning")

def greet2():
    print("hello good morning")

greet1()
# Out:
# hello good morning
# hello good night
# greet1 function starts
# hello good morning
# hello good night
# greet2 function starts
# hello good morning
# hello good morning

# %%
def greet1():
    print("greet2 function starts")
    greet2()
    print("hello good morning")

def greet2():
    print("greet1 function starts")
    greet1()
    print("hello good night")

greet2()
# Out:
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# ...
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[120], line 11
#       8     greet1()
#       9     print("hello good night")
# ---> 11 greet2()
#
# Cell In[120], line 8, in greet2()
#       6 def greet2():
#       7     print("greet1 function starts")
# ----> 8     greet1()
#       9     print("hello good night")
#
# Cell In[120], line 3, in greet1()
#       1 def greet1():
#       2     print("greet2 function starts")
# ----> 3     greet2()
#       4     print("hello good morning")
#
# Cell In[120], line 8, in greet2()
#       6 def greet2():
#       7     print("greet1 function starts")
# ----> 8     greet1()
#       9     print("hello good night")
#
# Cell In[120], line 3, in greet1()
#       1 def greet1():
#       2     print("greet2 function starts")
# ----> 3     greet2()
#       4     print("hello good morning")
#
#     [... skipping similar frames: greet2 at line 8 (1485 times), greet1 at line 3 (1484 times)]
#
# Cell In[120], line 3, in greet1()
#       1 def greet1():
#       2     print("greet2 function starts")
# ----> 3     greet2()
#       4     print("hello good morning")
#
# Cell In[120], line 8, in greet2()
#       6 def greet2():
#       7     print("greet1 function starts")
# ----> 8     greet1()
#       9     print("hello good night")
#
# Cell In[120], line 2, in greet1()
#       1 def greet1():
# ----> 2     print("greet2 function starts")
#       3     greet2()
#       4     print("hello good morning")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\iostream.py:664, in OutStream.write(self, string)
#     655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)
#     662
#     663     """
# --> 664     parent = self.parent_header
#     666     if not isinstance(string, str):
#     667         msg = f"write() argument must be str, not {type(string)}"  # type:ignore[unreachable]
#
# RecursionError: maximum recursion depth exceeded

# %%
 ######### Error code ###########
def inside_function():
    print(f"hello {name} good morning")
        # we need to sense here
        # name is not defined  not even globally
        # if i call this function def i will get error
    
def outside_function(name):
    inside_function()
outside_function('python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 10
#       8 def outside_function(name):
#       9    inside_function()
# ---> 10 outside_function('python')
#
# Cell In[126], line 9, in outside_function(name)
#       8 def outside_function(name):
# ----> 9    inside_function()
#
# Cell In[126], line 3, in inside_function()
#       2 def inside_function():
# ----> 3    print(f"hello {name} good morning")
#
# NameError: name 'name' is not defined

# %%
def inside_function():
    print(f"hello {name} good morning")

inside_function()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 4
#       1 def inside_function():
#       2     print(f"hello {name} good morning")
# ----> 4 inside_function()
#
# Cell In[132], line 2, in inside_function()
#       1 def inside_function():
# ----> 2     print(f"hello {name} good morning")
#
# NameError: name 'name' is not defined

# %%
def inside_function(name):
    print(f"hello {name} good morning")
    # is the variable defined anywhere

def outside_function(name):
    inside_function(name)

outside_function('python')
# Out:
# hello python good morning

# %%
def inside_function(name):
    print(f"hello {name} good morning")
inside_function('Naresh')
# Out:
# hello Naresh good morning

# %%
def outside_function(name):
    def inside_function(name):
        print(f"hello {name} good morning")
    inside_function('Naresh')

outside_function('Naresh')
# Out:
# hello Naresh good morning

# %%
def outside_function(name):
    def inside_function(name):
        print(f"hello {name} good morning")
    inside_function('Naresh')

outside_function('Naresh')
# Out:
# hello Naresh good morning

# %%
def add(a,b):
    print(a+b)
add(10,20)
# Out:
# 30

# %%
def MATH():
    def add(a,b):
        print(a+b)
    add(10,20)
MATH()
# Out:
# 30

# %%
def MATH1():
    def MATH():
        def add(a,b):
            print(a+b)
        add(10,20)
        MATH()
    MATH()

# %%
def MATH1():
    def MATH():

# %%
def MATH1():
    def MATH():
        def add(a,b):
            print(a+b)
        add(10,20)
    MATH()

MATH1()
# Out:
# 30

# %%
def MATH(a,b):
    def add():
        print(a+b)
    add()
MATH(10,20)
# Out:
# 30

# %%
def outside_function(name):
    def inside_function():
        print(f"hello {name} good morning")
    inside_function()

outside_function('Naresh')
# Out:
# hello Naresh good morning
